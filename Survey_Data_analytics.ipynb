# %%
#!conda install plotly -y

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.offline as py
import plotly.figure_factory as fig_fact
import warnings
warnings.filterwarnings('ignore')


pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E4DC-14BA
#
#  Directory of C:\Users\Rawat Shab\Desktop\data science\survey_data_analytics-2018
#
# 03-07-2019  10:19    <DIR>          .
# 03-07-2019  10:19    <DIR>          ..
# 17-06-2019  10:12    <DIR>          .ipynb_checkpoints
# 03-11-2018  22:35         1,360,985 freeFormResponses.csv
# 03-11-2018  22:35        41,189,695 multipleChoiceResponses.csv
# 03-06-2019  15:34             1,274 myplot.png
# 17-06-2019  20:57           225,517 Read file with directory.ipynb
# 17-06-2019  22:26           877,920 Survery_experience_analysis.ipynb
# 19-06-2019  10:57           677,926 SurveyDataAnalytics.py.ipynb
# 03-11-2018  22:35             8,449 SurveySchema.csv
# 18-06-2019  11:05            19,820 Survey_Data_analytics.ipynb
# 19-06-2019  10:43           166,930 temp.csv
#                9 File(s)     44,528,516 bytes
#                3 Dir(s)  29,556,269,056 bytes free

# %%
df=pd.read_csv("multipleChoiceResponses.csv")

# %%
temdf=df.head(50)
temdf.to_csv('temp.csv')

# %%
df.head()
# Out:
#   Time from Start to Finish (seconds)                                      Q1                                      Q1_OTHER_TEXT                           Q2                                         Q3                                                 Q4                                                 Q5                                                 Q6                                      Q6_OTHER_TEXT                                                 Q7                                      Q7_OTHER_TEXT                                                 Q8                                                 Q9                                                Q10                                         Q11_Part_1                                         Q11_Part_2                                         Q11_Part_3                                         Q11_Part_4                                         Q11_Part_5                                         Q11_Part_6  \
# ...

# %%
sns.countplot(y="Q1",data=df)

# %% [markdown]
# #### Age of People particpating in Survey

# %%
sns.countplot(y='Q2',data=df)

# %%
con_df=pd.DataFrame(df['Q3'].value_counts())
con_df['Country']=con_df.index
con_df.column=['number of preople','Country Name']
con_df=con_df.reset_index().drop('index',axis=1)
con_df
# Out:
#       Q3                                            Country
# 0   4716                           United States of America
# 1   4417                                              India
# 2   1644                                              China
# 3   1036                                              Other
# 4    879                                             Russia
# 5    736                                             Brazil
# 6    734                                            Germany
# 7    702  United Kingdom of Great Britain and Northern I...
# 8    604                                             France
# 9    604                                             Canada
# 10   597                                              Japan
# 11   485                                              Spain
# 12   394              I do not wish to disclose my location
# 13   355                                              Italy
# 14   330                                          Australia
# ...

# %%
sns.countplot(y='Q3',hue='Country',data=con_df.head(10))

# %%
sns.countplot(y='Q3',hue='Country',data=con_df.tail(10))

# %% [markdown]
# #### Top 5 Countries in Survey

# %%
con_df.tail(10)
# Out:
#     Q3                                    Country
# 49  76                         Hong Kong (S.A.R.)
# 50  74                                     Norway
# 51  74                                    Tunisia
# 52  73                                Philippines
# 53  73                                   Thailand
# 54  72                             Czech Republic
# 55  71                                    Morocco
# 56  71                          Republic of Korea
# 57  62                                    Austria
# 58   1  In which country do you currently reside?

# %%
Age distribution
# Out:
#   File "<ipython-input-13-c6fae0b45f68>", line 1
#     Age distribution
#                    ^
# SyntaxError: invalid syntax

# %%
df['Q2'].describe()
# Out:
# count     23860
# unique       13
# top       25-29
# freq       6159
# Name: Q2, dtype: object

# %%
df2=df[1:-1]
df2.head()
#df2.Q2=df2.Q2.astype(float)
# Out:
#   Time from Start to Finish (seconds)      Q1 Q1_OTHER_TEXT     Q2                        Q3                 Q4                                                 Q5              Q6 Q6_OTHER_TEXT                         Q7 Q7_OTHER_TEXT    Q8         Q9                            Q10                                         Q11_Part_1                                         Q11_Part_2                                         Q11_Part_3 Q11_Part_4                                         Q11_Part_5                                         Q11_Part_6 Q11_Part_7 Q11_OTHER_TEXT                                Q12_MULTIPLE_CHOICE Q12_Part_1_TEXT Q12_Part_2_TEXT Q12_Part_3_TEXT Q12_Part_4_TEXT Q12_Part_5_TEXT Q12_OTHER_TEXT       Q13_Part_1 Q13_Part_2 Q13_Part_3 Q13_Part_4 Q13_Part_5 Q13_Part_6 Q13_Part_7     Q13_Part_8 Q13_Part_9 Q13_Part_10 Q13_Part_11 Q13_Part_12 Q13_Part_13 Q13_Part_14 Q13_Part_15 Q13_OTHER_TEXT      Q14_Part_1    Q14_Part_2      Q14_Part_3 Q14_Part_4 Q14_Part_5 Q14_Part_6  \
# ...

# %%
age_plot=df2['Q2'].value_counts().reindex(['18-21','22-24',
                                            '25-29','30-34',
                                            '35-39','40-44',
                                             '45-49','50-54',
                                            '55-59','60-69',
                                            '70-79','80+'])
f,ax=plt.subplots()
age_plot.plot(ax=ax,
            color='r')
age_plot.plot(kind='bar',
             ax=ax,
             figsize=(14,3),title="Age Distribution")
# matplotlib axes object
# separate plot for each col
#

# %%
print("Young people of age 18-21 are",len(df2[df2['Q2']=='18-21']))
# Out:
# Young people of age 18-21 are 3037

# %%
df2['Q4'].value_counts().plot(
                            kind='barh',
                            title="Highest Education",
                            figsize=(14,4))

# %% [markdown]
# ### Profession of People PArticipating in Survey

# %%
sns.countplot(y='Q6',data=df2)

# %% [markdown]
# ### Field of Work

# %%
f,ax=plt.subplots(1,1, figsize=(9,6))
ax=sns.countplot(y='Q7',data=df)
plt.show()

# %%
f,(ax1,ax2)=plt.subplots(1,2, figsize=(9,6))
ax1=sns.countplot(y='Q7',data=df)
ax2=sns.countplot(y='Q5',data=df)
plt.show()

# %%
con_df.columns={'number representative':con_df['Q3'],
               'Country':con_df['Country']}
con_df.head()

# %% [markdown]
# ### Number of Years of experience

# %%
experience_plot=df['Q8'].value_counts().reindex(['0-1','1-2','2-3',
                                            '3-4','5-10',
                                            '10-15',
                                            ])
f,ax=plt.subplots()
experience_plot.plot(ax=ax,
            color='g')
experience_plot.plot(kind='bar',
             ax=ax,
             figsize=(14,3),title="Experience Distribution")

# %%
experience_plot=df['Q8'].value_counts().reindex(['0-1','1-2','2-3',
                                            '3-4','5-10',
                                            '10-15',])
type(experience_plot)
experience_plot

# %% [markdown]
# ### Compensations ($USD)

# %%
df['Q9'].unique()

# %%
salarydf=df['Q9'].value_counts().reindex(['10-20,000', '0-10,000',
       'I do not wish to disclose my approximate yearly compensation',
       '20-30,000', '125-150,000', '30-40,000', '50-60,000',
       '100-125,000', '90-100,000', '70-80,000', '80-90,000', '60-70,000',
       '400-500,000', '40-50,000', '150-200,000', '500,000+',
       '300-400,000', '200-250,000', '250-300,000'])
salarydf

# %%
# salarydf=pd.DataFrame(salarydf,
#                 columns=['Salary','Number_of_People'])
# salarydf.head()

# %%
print("Python lovers",len(df2[df2['Q16_Part_1']=='Python']))
print("people like r:",len(df2[df2['Q16_Part_2']=='R']))

# %%
#Plot the number of R and Python users by Occupation
data = df2[(df2['Q16_Part_1'].notnull()) &
              ((df2['Q16_Part_1'] == 'Python') | 
               (df2['Q16_Part_2'] == 'R'))]
plt.figure(figsize=(8, 7))
sns.countplot(y="Q6", hue="Q18",
              data=data)

# %% [markdown]
# ### number of young data scientist

# %%
print("Young people of age 18-21 are",len(df2[df2['Q2']=='18-21']))

# %%
yds=df2[df2['Q2']=='18-21']
yds
